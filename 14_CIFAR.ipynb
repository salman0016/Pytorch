# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
#net.to(device)

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
# !pip install ipywidgets==7.4.2
# Out:
# Requirement already satisfied: ipywidgets==7.4.2 in /home/salman/anaconda3/lib/python3.9/site-packages (7.4.2)
# Requirement already satisfied: ipython>=4.0.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipywidgets==7.4.2) (7.29.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipywidgets==7.4.2) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipywidgets==7.4.2) (5.1.0)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipywidgets==7.4.2) (3.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipywidgets==7.4.2) (5.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (6.1.12)
# Requirement already satisfied: ipython-genutils in /home/salman/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (0.1.2)
# Requirement already satisfied: pickleshare in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (3.0.20)
# Requirement already satisfied: backcall in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (4.8.0)
# Requirement already satisfied: pygments in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (58.0.4)
# Requirement already satisfied: decorator in /home/salman/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.4.2) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /home/salman/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (22.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/salman/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets==7.4.2) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/salman/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.4.2) (0.7.0)
# Requirement already satisfied: wcwidth in /home/salman/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.4.2) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.8.0)
# Requirement already satisfied: nbconvert in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (6.1.0)
# Requirement already satisfied: jinja2 in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.11.3)
# Requirement already satisfied: prometheus-client in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.11.0)
# Requirement already satisfied: argon2-cffi in /home/salman/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.14.6)
# Requirement already satisfied: pycparser in /home/salman/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/salman/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.3)
# Requirement already satisfied: defusedxml in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.7.1)
# Requirement already satisfied: testpath in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.0)
# Requirement already satisfied: bleach in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/salman/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.8.4)
# Requirement already satisfied: nest-asyncio in /home/salman/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.5.1)
# Requirement already satisfied: async-generator in /home/salman/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.10)
# Requirement already satisfied: webencodings in /home/salman/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.1)
# Requirement already satisfied: packaging in /home/salman/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/salman/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (3.0.4)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# bird  car   car   truck

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,  2000] loss: 2.237
# [1,  4000] loss: 1.893
# [1,  6000] loss: 1.674
# [1,  8000] loss: 1.602
# [1, 10000] loss: 1.504
# [1, 12000] loss: 1.463
# [2,  2000] loss: 1.392
# [2,  4000] loss: 1.363
# [2,  6000] loss: 1.349
# [2,  8000] loss: 1.307
# [2, 10000] loss: 1.288
# [2, 12000] loss: 1.250
# Finished Training

# %%
PATH = './cifar_net.pth'
torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
# Out:
# GroundTruth:  cat   ship  ship  plane

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join(f'{classes[predicted[j]]:5s}'
                              for j in range(4)))
# Out:
# Predicted:  cat   car   ship  ship

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the 10000 test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the 10000 test images: 55 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: plane is 45.9 %
# Accuracy for class: car   is 53.4 %
# Accuracy for class: bird  is 39.6 %
# Accuracy for class: cat   is 44.9 %
# Accuracy for class: deer  is 33.6 %
# Accuracy for class: dog   is 45.5 %
# Accuracy for class: frog  is 59.9 %
# Accuracy for class: horse is 69.7 %
# Accuracy for class: ship  is 84.2 %
# Accuracy for class: truck is 77.9 %
